# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
import math
import sys

# %% [markdown]
# # Get Links From List

# %%
url = "https://en.wikipedia.org/wiki/List_of_computer_scientists"


response = requests.get(url)
first_links_list = []

if response.status_code == 200:
    
 soup = BeautifulSoup(response.text, 'html.parser')

    
 h2_element = soup.find('div', {'class': 'mw-content-ltr mw-parser-output'})
 list_test=h2_element.find_all('ul')

 for ul_element in list_test:
      li_elements = ul_element.find_all('li')
      for li in li_elements:
            link = li.find('a')
            if link:
                href = link.get('href')
                if href:
                    full_link = f"https://en.wikipedia.org{href}"
                    first_links_list.append(full_link)
 links_to_exclude = []
 see_also_header = soup.find('span',id='See_also').parent
 see_also_div = see_also_header.find_next('div')
 see_also_ul = see_also_div.find_all('ul')
 for ul_element in see_also_ul:
      see_also_li_elements = ul_element.find_all('li')
      for li in see_also_li_elements:
        link = li.find('a')
        if link:
            href = link.get('href')
            if href:
                full_link = f"https://en.wikipedia.org{href}"
                links_to_exclude.append(full_link)
first_links_list = [link for link in first_links_list if link not in links_to_exclude]
print(first_links_list)
# Out:
# ['https://en.wikipedia.org/wiki/Atta_ur_Rehman_Khan', 'https://en.wikipedia.org/wiki/Wil_van_der_Aalst', 'https://en.wikipedia.org/wiki/Scott_Aaronson', 'https://en.wikipedia.org/wiki/Rediet_Abebe', 'https://en.wikipedia.org/wiki/Hal_Abelson', 'https://en.wikipedia.org/wiki/Serge_Abiteboul', 'https://en.wikipedia.org/wiki/Samson_Abramsky', 'https://en.wikipedia.org/wiki/Leonard_Adleman', 'https://en.wikipedia.org/wiki/Manindra_Agrawal', 'https://en.wikipedia.org/wiki/Luis_von_Ahn', 'https://en.wikipedia.org/wiki/Alfred_Aho', 'https://en.wikipedia.org/wiki/Frances_E._Allen', 'https://en.wikipedia.org/wiki/Gene_Amdahl', 'https://en.wikipedia.org/wiki/David_P._Anderson', 'https://en.wikipedia.org/wiki/Lisa_Anthony', 'https://en.wikipedia.org/wiki/Andrew_Appel', 'https://en.wikipedia.org/wiki/Cecilia_R._Aragon', 'https://en.wikipedia.org/wiki/Bruce_Arden', 'https://en.wikipedia.org/wiki/Angie_Jones', 'https://en.wikipedia.org/wiki/Sanjeev_Arora', 'https://en.wikipedia.org/wiki/Winifred_Asprey', 'https://en.wikipedia.org/wiki/John_Vincent_Atanasoff', 'https://en.wikipedia.org/wiki/Shakuntala_Atre', 'https://en.wikipedia.org/wiki/Lennart_Augustsson', 'https://en.wikipedia.org/wiki/Charles_Babbage', 'https://en.wikipedia.org/wiki/Charles_Bachman', 'https://en.wikipedia.org/wiki/Roland_Carl_Backhouse', 'https://en.wikipedia.org/wiki/John_Backus', 'https://en.wikipedia.org/wiki/David_F._Bacon', 'https://en.wikipedia.org/wiki/David_Bader_(computer_scientist)', 'https://en.wikipedia.org/wiki/Victor_Bahl', 'https://en.wikipedia.org/wiki/Anthony_James_Barr', 'https://en.wikipedia.org/wiki/Jean_Bartik', 'https://en.wikipedia.org/wiki/Andrew_Barto', 'https://en.wikipedia.org/wiki/Friedrich_L._Bauer', 'https://en.wikipedia.org/wiki/Rudolf_Bayer', 'https://en.wikipedia.org/wiki/Gordon_Bell', 'https://en.wikipedia.org/wiki/Steven_M._Bellovin', 'https://en.wikipedia.org/wiki/Cecilia_Berdichevsky', 'https://en.wikipedia.org/wiki/Tim_Berners-Lee', 'https://en.wikipedia.org/wiki/Daniel_J._Bernstein', 'https://en.wikipedia.org/wiki/Peter_Bernus', 'https://en.wikipedia.org/wiki/Jeff_Bezos', 'https://en.wikipedia.org/wiki/Abhay_Bhushan', 'https://en.wikipedia.org/wiki/Dines_Bj%C3%B8rner', 'https://en.wikipedia.org/wiki/Gerrit_Blaauw', 'https://en.wikipedia.org/wiki/Sue_Black_(computer_scientist)', 'https://en.wikipedia.org/wiki/David_Blei', 'https://en.wikipedia.org/wiki/Dorothy_Blum', 'https://en.wikipedia.org/wiki/Lenore_Blum', 'https://en.wikipedia.org/wiki/Manuel_Blum', 'https://en.wikipedia.org/wiki/Barry_Boehm', 'https://en.wikipedia.org/wiki/Corrado_B%C3%B6hm', 'https://en.wikipedia.org/wiki/Kurt_Bollacker', 'https://en.wikipedia.org/wiki/Jeff_Bonwick', 'https://en.wikipedia.org/wiki/Grady_Booch', 'https://en.wikipedia.org/wiki/George_Boole', 'https://en.wikipedia.org/wiki/Andrew_Donald_Booth', 'https://en.wikipedia.org/wiki/Kathleen_Booth', 'https://en.wikipedia.org/wiki/Anita_Borg', 'https://en.wikipedia.org/wiki/Bert_Bos', 'https://en.wikipedia.org/wiki/Mikhail_Botvinnik', 'https://en.wikipedia.org/wiki/Jonathan_Bowen', 'https://en.wikipedia.org/wiki/Stephen_R._Bourne', 'https://en.wikipedia.org/wiki/Harry_Bouwman', 'https://en.wikipedia.org/wiki/Robert_S._Boyer', 'https://en.wikipedia.org/wiki/Karlheinz_Brandenburg', 'https://en.wikipedia.org/wiki/Gilles_Brassard', 'https://en.wikipedia.org/wiki/Lawrence_M._Breed', 'https://en.wikipedia.org/wiki/Jack_E._Bresenham', 'https://en.wikipedia.org/wiki/Sergey_Brin', 'https://en.wikipedia.org/wiki/David_J._Brown_(computer_scientist)', 'https://en.wikipedia.org/wiki/Per_Brinch_Hansen', 'https://en.wikipedia.org/wiki/Sjaak_Brinkkemper', 'https://en.wikipedia.org/wiki/Fred_Brooks', 'https://en.wikipedia.org/wiki/Rod_Brooks', 'https://en.wikipedia.org/wiki/Margaret_Burnett', 'https://en.wikipedia.org/wiki/Michael_Butler_(computer_scientist)', 'https://en.wikipedia.org/wiki/Pino_Caballero_Gil', 'https://en.wikipedia.org/wiki/Tracy_Camp', 'https://en.wikipedia.org/wiki/Martin_Campbell-Kelly', 'https://en ...

# %% [markdown]
# ### Get name

# %%
def get_scientist_name(link):
    response= requests.get(link)
    if response.status_code == 200:
    
        soup = BeautifulSoup(response.text, 'html.parser')
        name=soup.find('span',{'class': 'mw-page-title-main'}).text
        if name:
            return name
        else:
            return 'unknown'

# %% [markdown]
# ### Get Awards

# %%
def get_scientist_awards(link):
    response= requests.get(link)
    if response.status_code == 200:
        
        soup = BeautifulSoup(response.text, 'html.parser')
        find_awards=0
        awards_table = soup.find('table',{'class': 'infobox biography vcard'})
        if(awards_table):
            awards_table_condition = awards_table.find('th', string= 'Awards')
            if awards_table_condition:
                awards_table_td = awards_table_condition.find_next('td',{'class' : 'infobox-data'})
                awards_table_list = awards_table_td.find_next('ul')
                awards=len(awards_table_list.find_all('li'))
                find_awards=1

        if find_awards==0:
            awards_header_condition = soup.find('span', {'id': 'Honors_&_Awards'})
            if awards_header_condition:
                awards_header = soup.find('span', {'id': 'Honors_&_Awards'}).parent
                awards_list=awards_header.find_next('ul')
                li_elements = list(awards_list.find_all('li'))
                awards=len(li_elements)
                find_awards=1
        
        if find_awards==1:
             return awards
        else:
             return 0

# %% [markdown]
# ### Get education

# %%
def get_scientist_education(link):
    response= requests.get(link)
    if response.status_code == 200:
    
        soup = BeautifulSoup(response.text, 'html.parser')
        find_education=0
        education_table = soup.find('table',{'class': 'infobox biography vcard'})
        if education_table:
            education_table_condition = education_table.find('th', string= 'Education')
            if education_table_condition:
                education_header= education_table_condition.parent
                education_table_td = education_header.find_next('td')
                education_list = education_table_td.find_next('> ul')
                if education_list:
                    education_text = ', '.join(li.get_text(strip=True) for li in ul_element.find_all('li'))
                    find_education=1
                education_a = education_table_td.find_all('a')
                if education_a and find_education==0:
                    education_text = ', '.join(a.get_text(strip=True) for a in education_table_td.find_all('a'))
                    find_education=1
            if find_education==0:
                alma_matter_condition = education_table.find('th', string= 'Alma mater')
                if alma_matter_condition:
                    alma_matter_header = alma_matter_condition.parent
                    alma_matter_td = alma_matter_header.find_next('td')
                    alma_matter_list = alma_matter_td.find_next('> ul')
                    if alma_matter_list:
                        education_text = ', '.join(li.get_text(strip=True) for li in ul_element.find_all('li'))
                        find_education=1

                    alma_matter_a = alma_matter_td.find_all('a')
                    if alma_matter_a and find_education==0 :
                        education_text = ', '.join(a.get_text(strip=True) for a in alma_matter_td.find_all('a'))
                        find_education=1

        if find_education==1:
            return education_text
        else:
             return 'NO_SAVE'

# %% [markdown]
# ### Into the CSV

# %%
# sv_filename = 'scientists_data.csv'

# # Headers
# headers = ['Name', 'Awards', 'Education']

# with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    
#    csv_writer = csv.writer(csv_file)

#    # Write the headers 
#    csv_writer.writerow(headers)

#    #write each scientist's information to the CSV file
#    for link in first_links_list:
#        name = get_scientist_name(link)
#        awards = get_scientist_awards(link)
#        education = get_scientist_education(link)
      

#        #Write the information
#        if education!='NO_SAVE' and not education.startswith('(') and not education.startswith('['):
#            csv_writer.writerow([name, awards, education])

# %% [markdown]
# ### Clean Garbage

# %%
csv_file_path = 'scientists_data.csv'
df = pd.read_csv(csv_file_path)
all_institutes=[]
for row in df['Education']:
    institutes = [inst.strip() for inst in row.split(',')]
    all_institutes.extend(institutes)

unique_institutes = list(set(all_institutes))
unique_institutes.remove('Ph.D')
unique_institutes.remove('B.S.')
unique_institutes.remove('[11]')
unique_institutes.remove('[2]')
unique_institutes.remove('S.B.')
unique_institutes.remove('BSc.')
unique_institutes.remove('es')
unique_institutes.remove('BE')
unique_institutes.remove('[1]')
unique_institutes.remove('[3]')
unique_institutes.remove('[5]')
unique_institutes.remove('PhD')
unique_institutes.remove('[4]')
unique_institutes.remove('MSc')
unique_institutes.remove('B.Sc.')
unique_institutes.remove('BSc')
unique_institutes.remove('BASc')
unique_institutes.remove('Ph.D.')
unique_institutes.remove('1969')
unique_institutes.remove('MS')
unique_institutes.remove('M.S.')
unique_institutes.remove('SM')
unique_institutes.remove('BS')
unique_institutes.remove('SB')
unique_institutes.remove('BA')
unique_institutes.remove('AB')
unique_institutes.remove('B.A.')
unique_institutes.remove('Diplom')
unique_institutes.remove('')
print(df)
# Out:
#                     Name  Awards  \
# 0    Atta ur Rehman Khan      10
# 1         Scott Aaronson       4
# 2           Rediet Abebe       3
# 3            Hal Abelson       1
# 4        Serge Abiteboul       4
# ..                   ...     ...
# 504       Stanley Zdonik       0
# 505        Hussein Zedan       0
# 506   Shlomo Zilberstein       0
# 507       Jill Zimmerman       0
# 508          Konrad Zuse       5
#
#                                              Education
# 0             University of Malaya, COMSATS University
# 1    Cornell University, University of California, ...
# 2    Cornell University, University of Cambridge, H...
# 3    Princeton University, Massachusetts Institute ...
# 4                    University of Southern California
# ..                                                 ...
# 504              Massachusetts Institute of Technology
# 505                              University of Bristol
# 506  University of California, Berkeley, Technion –...
# 507         Purdue University, University of Minnesota
# 508                     Technical University of Berlin
#
# [509 rows x 3 columns]

# %% [markdown]
# ### Node Class

# %%
class peer_node:
    def __init__(self,df,node_num):
        self.values=df
        self.node_num=node_num
        self.predecessor=0
        self.fingertable = pd.DataFrame(columns=['successors', 'index_of_peers'])
        self.key=[]
    def set_key(self,key):
        self.key=key
    def get_key(self,key):
        self.key.append(key)
    def merge_key_list(self,node2):
        self.key=self.key+node2.key
    def set_finger(self,succ,index):
        self.fingertable['successors'] = succ
        self.fingertable['index_of_peers'] = index

# %% [markdown]
# ### Chord Cirlce Class

# %%
class Chord_circle:
    def __init__(self,institutes,df):
        self.institutes=institutes
        self.df=df
        self.max_node=0
        self.peers=[]
        self.fake_hash_table=pd.DataFrame(columns=['number_of_key','key','search_key'])
    def remove_finger_tables(self):
        for peer in self.peers:
            peer.fingertable=pd.DataFrame(columns=['successors', 'index_of_peers'])
    def create_finger_table_for_all(self):
        length=len(self.peers)
        m=math.ceil(math.log2(length))
        temp_start=0
        for peer in self.peers:
            temp_table=[]
            index_table=[]
            first_attempt=0
            for i in range(1,m+1):
                ok=0
                start=peer.node_num+2**(i-1)
                #if peer.node_num==405:
                    #print("FINGERTABLE-->"+ str(start)+ " WITH MAXNODE--> "+str(self.max_node)) #DEBUGGING
                if start > self.max_node:
                    start= start - self.max_node -1
                if (self.return_to_start(peer.node_num)) & (first_attempt==0):
                    #print("THIS IS NODE_NUM--> "+str(peer.node_num)) #DEBUGGING
                    start=0
                    first_attempt=1
                while(ok==0):
                    for index,s_peer in enumerate(self.peers):
                        if s_peer.node_num==start:
                            temp_table.append(start)
                            index_table.append(index)
                            ok=1
                    start+=1
               
            peer.set_finger(temp_table,index_table) 
    def renew_max_node(self):
        self.max_node=int(self.peers[len(self.peers)-1].node_num)
        #print("TYPE OF MAX NODE -->"+str(self.max_node))
        #print("NEW MAX NODE --> "+str(self.max_node)) DEBUGGING
    def create_list_of_peers(self):
        counter=0

        for institute in self.institutes:
            result_rows = []
            self.fake_hash_table.loc[len(self.fake_hash_table)] = {'number_of_key': counter, 'key': institute,'search_key': counter}

            for index, row in self.df.iterrows():
        
                if institute in row['Education']:
                    result_rows.append(row.drop('Education'))


            result_df = pd.DataFrame(result_rows).reset_index(drop=True)
            result_df['institute'] = institute
            peer=peer_node(result_df,counter)
            counter+=1
            peer.get_key(institute)
            self.peers.append(peer)
        self.renew_max_node()
        self.create_finger_table_for_all()
    def return_to_start(self,i):
        #print("MAX="+str(self.max_node)) DEBUGGING
        if (i != 0) & ((i %  self.max_node) == 0):
            return 1 
        else:
            return 0
    def key_to_number(self,lookup_key):
        get_num=None
        for index,row in self.fake_hash_table.iterrows():
            if row['key'].lower()==lookup_key.lower():
                get_num=row['search_key']
                #print('SEARCH KEY IS --->'+str(get_num)) DEBUGGING
                break
        if get_num==None:
            print("No archive for this Institute")
        return get_num
        #print(get_num) DEBUGGING
    def lookup(self,key,threshold):
        node_to_search=self.key_to_number(key)
        print(f"The key is --> {node_to_search}")
        #print('I WANT NODE'+str(node_to_search)) DEBUGGING
        if node_to_search!=None:
            res_df=pd.DataFrame()
            this_node=self.peers[0]
            while(this_node.node_num!=node_to_search):
                print(f"Searching {this_node.node_num} fingertable")
                ft=this_node.fingertable['successors']
                print(f"{ft}") #DEBUGGING
                for index,row in this_node.fingertable.iterrows():
                    if row['successors']==node_to_search:
                        #print('1st if-->'+str(row['successors']))  #DEBBUGING
                            index=row['index_of_peers']
                            this_node=self.peers[index]
                            break
                        
                    elif row['successors']>node_to_search :
                        #print('2nd if') #DEBUGGING
                        this_node_index = index - 1
                        if this_node_index >= 0:
                            previous_row = this_node.fingertable.at[this_node_index, 'index_of_peers']
                            print_row = this_node.fingertable.at[this_node_index, 'successors']
                            print(f'Previous_row = {print_row}')
                            this_node=self.peers[previous_row]
                            break
                    else:
                        #print('3rd if') #DEBUGGING
                        if index == this_node.fingertable.index[-1]:
                            print_this=this_node.fingertable['successors'].max()
                            print(f'Max row = {print_this}')
                            correct_index=this_node.fingertable['index_of_peers'].max()
                            this_node=self.peers[correct_index]
                        else: continue
               
            res_df=this_node.values
            filtered_rows = res_df[(res_df['Awards'] >= threshold) & (res_df['institute']==key)]
            print(filtered_rows)
    def leave_circle(self,node):
        big=1
        for peer in self.peers:
            if peer.node_num==node:
                delete_this_node=peer
                big=0
        if big==1:
            print('There is no such node')
        elif node<=self.max_node:
            #if self.return_to_start(node):
                nn = delete_this_node.fingertable['index_of_peers'].iloc[0]
                print(f'NN is -->{nn}')
                next_node=self.peers[nn]
                next_node.values=pd.concat([next_node.values,delete_this_node.values],ignore_index=True)
                next_node.merge_key_list(delete_this_node)
                self.fake_hash_table.loc[self.fake_hash_table['search_key']==node,'search_key']=next_node.node_num                    
        
                self.peers.remove(delete_this_node)
                self.renew_max_node()
                self.remove_finger_tables()
                self.create_finger_table_for_all()
    def show(self):
        for peer in self.peers:
            key_str = ', '.join(map(str, peer.key))
            print(str(peer.node_num) + ' --> ' + key_str)
    def join_circle(self):
        empty_slots=[]
        last=0
        max_empty=self.fake_hash_table['number_of_key'].iloc[-1]
        stop=max_empty+1
        if max_empty==self.max_node:
            stop=stop+1
        for i in range(0,stop):
            if i>self.max_node:
                empty_slots.append(i)
            elif i<len(self.peers)-1:
                #print(self.peers[i].node_num) DEBUGGING
                #print(f'Max node is {self.max_node} and i is {i+1}')
                D=self.peers[i+1].node_num-self.peers[i].node_num
                if D>1 : 
                    for j in range(self.peers[i].node_num+1,self.peers[i+1].node_num):
                        empty_slots.append(j)
        print("Choose a slot from these:")
        for slot in empty_slots:
            print(slot)
        sys.stdout.flush() 
        chosen_node=int(input("Enter here ---> "))
        print(chosen_node)
        if chosen_node not in empty_slots:
            print("Thats not a valid node!")
        elif chosen_node==max(empty_slots) &  self.fake_hash_table['number_of_key'].iloc[-1]!=chosen_node:
            empty_df=pd.DataFrame()
            peer_n=peer_node(empty_df,chosen_node)
            self.peers.append(peer_n)
        else:
            new_keys=[]
            new_node_df=pd.DataFrame()
            pre=chosen_node-1
            while pre in empty_slots and pre>=0:
                pre=pre-1
            if chosen_node==max(empty_slots):
                next_node_num=self.peers[0].node_num
                last=1
            else:
                suc=chosen_node+1
                while suc in empty_slots:
                    suc=suc+1
                next_node_num=suc
                while pre in empty_slots and pre>=0:
                    pre=pre-1
                    if pre<0:
                        pre=self.max_node
                
            self.fake_hash_table.loc[(self.fake_hash_table['number_of_key'] <= chosen_node) & (self.fake_hash_table['number_of_key'] >pre), 'search_key'] = chosen_node
            condition=(self.fake_hash_table['search_key'] <= chosen_node) & (self.fake_hash_table['search_key'] >pre)
            selected_rows = self.fake_hash_table[condition]
            print(selected_rows)
            list_try=selected_rows['key'].tolist()
            for peer in self.peers:
                if peer.node_num==next_node_num:
                    split_condition = peer.values['institute'].isin(list_try)
                    new_node_df=peer.values[split_condition]
                    peer.values=peer.values[~split_condition]
                    peer_index=self.peers.index(peer)
                    for key in list_try:
                        new_keys.append(key)
                        peer.key.remove(key)
                    #print(peer.values)
            # self.peers(next_node).value
            peer_n=peer_node(new_node_df,chosen_node)
            peer_n.set_key(new_keys)
            if last==1:
                print(new_node_df)
                self.peers.append(peer_n)
            else:
                self.peers.insert(peer_index,peer_n)
        self.renew_max_node()
        self.remove_finger_tables()
        self.create_finger_table_for_all()

# %% [markdown]
# ## Δημιουργία αντικειμένου
# ### Δημιουργία Chord Circle

# %%
Chord=Chord_circle(unique_institutes,df)
Chord.create_list_of_peers()

# %% [markdown]
# ## Εμφάνιση κύκλου

# %%
Chord.show()
# Out:
# 0 --> Raffles Institution
# 1 --> Chemistry
# 2 --> University of California
# 3 --> Rice University
# 4 --> College Park
# 5 --> University of Madras
# 6 --> D.Phil.
# 7 --> Wolfson College
# 8 --> Chalmers University of Technology
# 9 --> Harvard University
# 10 --> De Anza College
# 11 --> University of Calcutta
# 12 --> National Taiwan University
# 13 --> Miami University
# 14 --> Official School of the Road Engineers' Corps of Madrid
# 15 --> Oregon State University
# 16 --> COMSATS University
# 17 --> Dragon School
# 18 --> McMaster University
# 19 --> Tsinghua University
# 20 --> American University
# 21 --> University of Wisconsin-Madison
# 22 --> Carleton University
# 23 --> Colorado College
# 24 --> École Polytechnique
# 25 --> University of Virginia
# 26 --> Georgia Institute of Technology
# 27 --> Pierre and Marie Curie University
# 28 --> Leningrad State University
# 29 --> St John's College
# 30 --> mathematics
# 31 --> Hebrew University of Jerusalem
# 32 --> Rhodes College
# 33 --> Keio University
# 34 --> Polish Academy of Sciences
# 35 --> Los Angeles
# 36 --> Ghent University
# 37 --> Technion – Israel Institute of Technology
# 38 --> Supélec
# 39 --> Indiana University Jacobs School of Music
# 40 --> Bar-Ilan University
# 41 --> Tennessee State University
# 42 --> University of Arizona
# 43 --> Indian Institute of Technology Delhi
# 44 --> Dalhousie University
# 45 --> École Nationale Supérieure des Mines de Nancy
# 46 --> Weizmann Institute
# 47 --> University of Grenoble
# 48 --> Ludwig-Maximilians-Universität
# 49 --> Jadavpur University
# 50 --> MTech
# 51 --> University of Tokyo
# 52 --> University of Bonn
# 53 --> University of Edinburgh
# 54 --> University of Nebraska - Lincoln
# 55 --> Shanghai Jiao Tong University
# 56 --> University of Rome
# 57 --> National Hsinchu Senior High School
# 58 --> Dartmouth College
# 59 --> MIT
# 60 --> St. Xavier High School
# 61 --> Free University of Amsterdam
# 62 --> University of Illinois at Urbana–Champaign
# 63 --> University of Western Ontario
# 64 --> Carnegie Mellon
# 65 --> University of Erlangen-Nuremberg
# 66 --> M.A.
# 67 --> University of Iowa
# 68 --> Uppsala University
# 69 --> Michigan State University
# 70 --> Newcastle University
# 71 --> Université Laval
# 72 --> University of Tsukuba
# 73 --> University of Dortmund
# 74 --> Stanford
# 75 --> George Washington University School of Engineering and Applied Science
# 76 --> University of Pittsburgh
# 77 --> Peterhouse
# 78 --> University of Liverpool
# 79 --> RPI
# 80 --> University of Michigan
# 81 --> University College
# 82 --> Lomonosov Moscow State University
# 83 --> Selwyn College
# 84 --> Durham University
# 85 --> IIT Madras (M.Tech.
# 86 --> TU Berlin
# 87 --> Duke University
# 88 --> Cornell University
# 89 --> Cambridge University
# 90 --> Rutgers University
# 91 --> University of Florida
# 92 --> Gothenburg
# 93 --> IIT Bombay
# 94 --> University of Southern California
# 95 --> M.Sc.
# 96 --> University of Kansas City
# 97 --> University of Illinois at Urbana-Champaign
# 98 --> University of Washington
# 99 --> Peking University
# 100 --> Royal Institute of Technology
# 101 --> University of Nebraska
# 102 --> Massey University
# 103 --> Shimane University
# 104 --> London South Bank University
# 105 --> University of Pretoria
# 106 --> University of Warsaw
# 107 --> Davis
# 108 --> University of California at Berkeley
# 109 --> Lancaster University
# 110 --> Université du Québec à Montréal
# 111 --> King's College
# 112 --> Göteborg University
# 113 --> University of Cambridge
# 114 --> Indian Statistical Institute
# 115 --> University of Illinois at Urbana Champaign
# 116 --> Diploma in Computer Science
# 117 --> Seattle University
# 118 --> Georgia Tech
# 119 --> computer engineering
# 120 --> University of Vienna
# 121 --> Eindhoven University of Technology
# 122 --> South High School
# 123 --> Athens Polytechnic
# 124 --> Cleveland State University
# 125 --> Sharif University of Technology
# 126 --> Brock University
# 127 --> Imperial College London
# 128 --> Westminster School
# 129 --> Moscow State University
# 130 --> Iowa State University
# 131 --> UC San Diego
# 132 --> Sunderland Polytechnic
# 133 --> Kanpur
# 134 --> Indian Institute of Technology
# 135 --> Columbia University
# 136 --> Wellesley College
# 137 --> Bachelor's degree
# 138 --> University of California - Berkeley
# 139 --> University of Colorado
# 140 --> University of Toronto
# 141 --> Pune
# 142 --> King Saud University
# 143 --> IIT Delhi
# 144 --> Mount Holyoke College
# 145 --> Queens College
# 146 --> University College London
# 147 --> Kalamazoo College
# 148 --> Exeter College
# 149 --> Technical University of Madrid
# 150 --> Wilberforce University
# 151 --> ETH Zurich
# 152 --> University of Heidelberg
# 153 --> Quai d'Orsay
# 154 --> Jesus College
# 155 --> Carnegie Mellon University (Ph.D.)
# 156 --> University of Texas at Austin
# 157 --> University of Malaya
# 158 --> Welsh College of Advanced Technology
# 159 --> Claremont Graduate University
# 160 --> Brooklyn College
# 161 --> University of Calgary
# 162 --> Université Pierre et Marie Curie
# 163 --> Cand.scient.
# 164 --> New York University
# 165 --> University of British Columbia
# 166 --> Université de Montréal
# 167 --> New Delhi
# 168 --> Weizmann Institute of Science
# 169 --> Delft University of Technology
# 170 --> master's degree
# 171 --> Santa Clara University
# 172 --> Kyoto University
# 173 --> University of Bremen
# 174 --> Swedish Institute of Computer Science
# 175 --> Rajabazar Science College
# 176 --> University of Rochester
# 177 --> Radcliffe College
# 178 --> Berkeley
# 179 --> École Polytechnique Fédérale de Lausanne
# 180 --> Joseph Fourier University
# 181 --> University of Massachusetts
# 182 --> New Zealand
# 183 --> Bates College
# 184 --> University of Bridgeport
# 185 --> University at Albany
# 186 --> U.S. Air Force Academy
# 187 --> Caltech
# 188 --> University of Pisa
# 189 --> UCLA
# 190 --> Wayne State University
# 191 --> University of California at Irvine
# 192 --> Visvesvaraya National Institute of Technology Nagpur
# 193 --> University of Wisconsin–Madison
# 194 --> Stony Brook University
# 195 --> University of Houston
# 196 --> University of Colorado Boulder
# 197 --> School of Oriental and African Studies
# 198 --> Queen Mary College
# 199 --> Harvard Law School
# 200 --> Amherst College
# 201 --> Université de Nancy
# 202 --> Stourbridge
# 203 --> Carnegie Mellon University
# 204 --> Xavier University
# 205 --> Politecnico di Milano
# 206 --> Stockholm University
# 207 --> Technical University of Berlin
# 208 --> University of Oxford
# 209 --> Oxford
# 210 --> Aarhus University
# 211 --> Carleton College
# 212 --> University of Warwick
# 213 --> Indiana University
# 214 --> Wesleyan University
# 215 --> Ealing Grammar School for Girls
# 216 --> University of Paris
# 217 --> University of Illinois Urbana-Champaign
# 218 --> Technical University of Munich
# 219 --> University of Science and Technology of China
# 220 --> University of Illinois
# 221 --> Brown University
# 222 --> University at Buffalo
# 223 --> Simmons College
# 224 --> University of St. Thomas
# 225 --> National Technical University of Athens
# 226 --> MIT Media Lab
# 227 --> Boulder
# 228 --> Trinidad and Tobago
# 229 --> Eastern Nazarene College
# 230 --> Tufts College
# 231 --> University of Minnesota
# 232 --> Chalmers Institute of Technology
# 233 --> Case Institute of Technology
# 234 --> UC Berkeley
# 235 --> Institute of Control Sciences
# 236 --> Utrecht University
# 237 --> University of Colorado at Boulder
# 238 --> State University of New York at Stony Brook
# 239 --> Aston University
# 240 --> University of Geneva
# 241 --> Southern Methodist University
# 242 --> University of Western Australia
# 243 --> Massachusetts Institute of Technology
# 244 --> University of Marburg
# 245 --> Doncaster Grammar School for Boys
# 246 --> Gateway High School
# 247 --> Madras
# 248 --> Technische Universität München
# 249 --> Nabadwip Bakultala High School
# 250 --> La Trobe University
# 251 --> Johns Hopkins University
# 252 --> The Queen's College
# 253 --> ETH Zürich
# 254 --> University of Wisconsin
# 255 --> University of Poona
# 256 --> Aarhus U.
# 257 --> Washington University in St. Louis
# 258 --> M.Eng.
# 259 --> Bangalore University
# 260 --> King's College London
# 261 --> Flinders University
# 262 --> Chicago State University
# 263 --> University of Pennsylvania
# 264 --> Vanderbilt University
# 265 --> Queen Mary University of London
# 266 --> University of Reading
# 267 --> University of Trieste
# 268 --> Indian Institute of Technology Madras
# 269 --> Menoufia University
# 270 --> Haverford College
# 271 --> Santa Barbara
# 272 --> Ohio State University
# 273 --> University of Alberta
# 274 --> Eötvös Loránd University
# 275 --> Dresden University of Technology
# 276 --> Mumbai
# 277 --> City College of New York
# 278 --> Kharagpur
# 279 --> Kharkov Polytechnic Institute
# 280 --> Arizona State University
# 281 --> Uzbek State University
# 282 --> St. Mary's College of California
# 283 --> University of Karlsruhe
# 284 --> University of North Carolina at Chapel Hill
# 285 --> IIT Kanpur
# 286 --> University of Waterloo
# 287 --> Ludwig Maximilian University of Munich
# 288 --> Polytechnic Institute of Brooklyn
# 289 --> Cornell
# 290 --> University of Bristol
# 291 --> VU University Amsterdam
# 292 --> Queen's University
# 293 --> The College of William and Mary
# 294 --> Churchill College
# 295 --> ESIEE Paris
# 296 --> University of Copenhagen
# 297 --> Northeastern University
# 298 --> University of Helsinki
# 299 --> Gresham's School
# 300 --> Mathematics
# 301 --> Vassar College
# 302 --> Delhi
# 303 --> University of Manchester
# 304 --> Stockholm
# 305 --> University of Sydney
# 306 --> University of Lisbon
# 307 --> Boston University
# 308 --> Highgate School
# 309 --> Indian Institute of Science
# 310 --> University of Glasgow
# 311 --> Technion
# 312 --> Amherst
# 313 --> University of London
# 314 --> King Edward VI College
# 315 --> Earlham College
# 316 --> Modern School
# 317 --> U.C. Berkeley
# 318 --> Dublin
# 319 --> Moscow University
# 320 --> University of Portland
# 321 --> University of Chicago
# 322 --> Pontifical Catholic University of Rio de Janeiro
# 323 --> St. Columba's School
# 324 --> Stanford University
# 325 --> University of New South Wales
# 326 --> Cambridge
# 327 --> San Diego State University
# 328 --> University of the West Indies
# 329 --> Knox College
# 330 --> South Dakota State University
# 331 --> North Carolina State University
# 332 --> Dr. rer. nat.
# 333 --> Illinois Institute of Technology
# 334 --> Warren Wilson College
# 335 --> University of Oslo
# 336 --> Southern Illinois University
# 337 --> University of Tehran
# 338 --> Eton College
# 339 --> Instituto Superior Técnico
# 340 --> University of Southampton
# 341 --> Sherborne School
# 342 --> University of New Mexico
# 343 --> Acadia University
# 344 --> MA
# 345 --> San Diego
# 346 --> Bielefeld University
# 347 --> New Jersey Institute of Technology
# 348 --> Carnegie Institute of Technology
# 349 --> Memphis State University
# 350 --> Fudan University
# 351 --> Santa Cruz
# 352 --> Harvey Mudd College
# 353 --> Calcutta University
# 354 --> Princeton University
# 355 --> Technical University of Denmark
# 356 --> electrical engineering
# 357 --> Harvard
# 358 --> Tallinn University of Technology
# 359 --> University of Hildesheim
# 360 --> New Mexico State University
# 361 --> The Hebrew University of Jerusalem
# 362 --> Monterrey Institute of Technology and Higher Education
# 363 --> Computer Science
# 364 --> MIT Sloan School of Management
# 365 --> Poznań University of Technology
# 366 --> Yale University
# 367 --> La Sapienza University of Rome
# 368 --> College of Engineering
# 369 --> University of Göttingen
# 370 --> Leiden University
# 371 --> Oberlin College
# 372 --> Wilson College
# 373 --> Course 6 - Electrical Engineering and Computer Science
# 374 --> University of Wisconsin - Madison
# 375 --> Cefups Academy
# 376 --> Northwest Missouri State Teachers College
# 377 --> University of Freiburg
# 378 --> Swarthmore College
# 379 --> Purdue University
# 380 --> Kharkov State University
# 381 --> UT Austin
# 382 --> University of Utah
# 383 --> Manhattan College
# 384 --> Clare College
# 385 --> B.Tech.)
# 386 --> San Francisco
# 387 --> Newnham College
# 388 --> New York University Tandon School of Engineering
# 389 --> University of Tennessee
# 390 --> University of Tübingen
# 391 --> Indian Institute of Technology Kanpur
# 392 --> University of Utah College of Engineering
# 393 --> Trinity College
# 394 --> Lehigh University
# 395 --> California Institute of Technology
# 396 --> Oxford University
# 397 --> Old Dominion University
# 398 --> Russian Academy of Sciences
# 399 --> University of Maryland
# 400 --> University of Amsterdam
# 401 --> ALB
# 402 --> Tel Aviv University
# 403 --> University of Cincinnati
# 404 --> American University in Cairo
# 405 --> University of Bombay
# 406 --> Brandeis University

# %% [markdown]
# ## Εμφάνιση fake_hash_table

# %%
Fake_has_table=Chord.fake_hash_table
print(Fake_has_table)
# Out:
#      number_of_key                           key  search_key
# 0                0           Raffles Institution           0
# 1                1                     Chemistry           1
# 2                2      University of California           2
# 3                3               Rice University           3
# 4                4                  College Park           4
# ..             ...                           ...         ...
# 402            402           Tel Aviv University         402
# 403            403      University of Cincinnati         403
# 404            404  American University in Cairo         404
# 405            405          University of Bombay         405
# 406            406           Brandeis University         406
#
# [407 rows x 3 columns]

# %% [markdown]
# ## Leave Circle κάποιων κόμβων

# %%
Chord.leave_circle(11)
Chord.leave_circle(12)
Chord.leave_circle(13)
Chord.leave_circle(311)
Chord.leave_circle(88)
Chord.leave_circle(173)
Chord.leave_circle(389)
Chord.leave_circle(404)
Chord.leave_circle(405)
Chord.leave_circle(406)
# Out:
# NN is -->12
# NN is -->12
# NN is -->12
# NN is -->309
# NN is -->86
# NN is -->170
# NN is -->384
# NN is -->398
# NN is -->398
# NN is -->0

# %% [markdown]
# ## Join Circle κάποιων κόμβων

# %%
Chord.join_circle()
# Out:
# Choose a slot from these:
# 11
# 12
# 13
# 88
# 173
# 311
# 389
# 404
# 405
# 406
# 406
#      number_of_key                           key  search_key
# 404            404  American University in Cairo         406
# 405            405          University of Bombay         406
# 406            406           Brandeis University         406
#                                     Name  Awards                     institute
# 1                      Janet L. Kolodner       8           Brandeis University
# 2                         Leslie Lamport       6           Brandeis University
# 3                          Murray Turoff       5           Brandeis University
# 4                          Mathai Joseph       5          University of Bombay
# 5  Brian Harris (translation researcher)       0  American University in Cairo

# %% [markdown]
# ## LookUps

# %%
Chord.lookup("University of Cambridge",0)
# Out:
# The key is --> 113
# Searching 0 fingertable
# 0      1
# 1      2
# 2      4
# 3      8
# 4     16
# 5     32
# 6     64
# 7    128
# 8    256
# Name: successors, dtype: int64
# Previous_row = 64
# Searching 64 fingertable
# 0     65
# 1     66
# 2     68
# 3     72
# 4     80
# 5     96
# 6    128
# 7    192
# 8    320
# Name: successors, dtype: int64
# Previous_row = 96
# Searching 96 fingertable
# 0     97
# 1     98
# 2    100
# 3    104
# 4    112
# 5    128
# 6    160
# 7    224
# 8    352
# Name: successors, dtype: int64
# Previous_row = 112
# Searching 112 fingertable
# 0    113
# 1    114
# 2    116
# 3    120
# 4    128
# 5    144
# 6    176
# 7    240
# 8    368
# Name: successors, dtype: int64
#                                     Name  Awards                institute
# 0                           Rediet Abebe       3  University of Cambridge
# 1                       Rosemary Candlin       0  University of Cambridge
# 2                    Christopher J. Date       0  University of Cambridge
# 3               Charlotte Froese Fischer       4  University of Cambridge
# 4                        Geoffrey Hinton       9  University of Cambridge
# 5                          Mathai Joseph       5  University of Cambridge
# 6                          Derek McAuley       1  University of Cambridge
# 7                           Alan Mycroft       0  University of Cambridge
# 8                          Mike Paterson      10  University of Cambridge
# 9                     Simon Peyton Jones       2  University of Cambridge
# 10                     Cicely Popplewell       0  University of Cambridge
# 11  Martin Richards (computer scientist)       2  University of Cambridge
# 12                  C. J. van Rijsbergen       0  University of Cambridge
# 13                     Bjarne Stroustrup      11  University of Cambridge
# 14                        Chai Keong Toh       3  University of Cambridge
# 15                        Leslie Valiant       6  University of Cambridge
# 16    David Wheeler (computer scientist)       6  University of Cambridge
# 17                          Yorick Wilks      19  University of Cambridge
# 18                         Sophie Wilson       6  University of Cambridge
# 19                          Neil Wiseman       0  University of Cambridge
# 20                      Beatrice Worsley       0  University of Cambridge
